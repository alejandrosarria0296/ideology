# %% [markdown]
# ## Libraries and UDFs

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.ml import Pipeline
from pyspark.ml.feature import Tokenizer, StopWordsRemover
from pyspark.ml.fpm import FPGrowth
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, StringType
import re

spark = SparkSession \
        .builder \
        .appName("frequent_itemsets") \
        .getOrCreate()

# %%
def clean_tokens(tokens):
    if not tokens:
        return []
    valid_word_pattern = re.compile(r"^[a-zA-ZáéíóúñÁÉÍÓÚÑüÜ]+$")
    return [token for token in tokens if valid_word_pattern.match(token)]
clean_tokens_udf = udf(clean_tokens, ArrayType(StringType()))

# %% [markdown]
# ## Preprocessing

# %%
path = r"../data/interventions_sample.csv"
interventions_sample = spark.read.csv(path, header=True)
int_df = interventions_sample.select("session_id", "intervention_id", 
                                     "intervention_text", "intervention_words")

# %%
path = r"../data/sample_clusters.csv" 
df = spark.read.csv(path, header=True)

# %%
int_df = int_df.join(df.select("intervention_id", "cluster"), on="intervention_id", how="inner")
int_df.show()
# Out:
# +---------------+--------------+--------------------+--------------------+-------+
# |intervention_id|    session_id|   intervention_text|  intervention_words|cluster|
# +---------------+--------------+--------------------+--------------------+-------+
# |         451824|gaceta_459 (7)|de acuerdo con el...|['acciones', 'cuá...|      0|
# |         451621|    gaceta_852|albán urbano luis...|['carlos', 'casti...|      2|
# |         451599|    gaceta_852|presidente el sig...|['artículos', 'av...|      4|
# |         451438| gaceta_68 (7)|perdone un segund...|['comisión', 'deb...|      1|
# |         451192|gaceta_456 (6)|antes de empezar ...|['asistir', 'comp...|      1|
# |         451071|   gaceta_1536|celular 318862010...|['aceta', 'celula...|      3|
# |         450768|gaceta_633 (1)|un segundo ya nos...|['activamos', 'al...|      0|
# |         450662|gaceta_390 (6)|doctora lo que pa...|['afectados', 'ci...|      0|
# |         450234| gaceta_49 (9)|continúa el señor...|['anglicana', 'ap...|      1|
# |         450076|gaceta_134 (7)|señor presidente,...|['después', 'día'...|      1|
# |         450007|    gaceta_634|:  es cierto este...|['agenda', 'cambi...|      0|
# |         449987|    gaceta_634|austed senador al...|['alirio', 'aquí'...|      1|
# |         449982|    gaceta_634|martes, 6 de juni...|['aquí', 'casa', ...|      0|
# |         449841| gaceta_21 (6)|gracias señor pre...|['breve', 'consid...|      0|
# |         449308|gaceta_116 (8)|gracias señor pre...|['asciende', 'cad...|      0|
# |         449293|gaceta_116 (8)|artículo 1°. obje...|['ambiental', 'am...|      0|
# |         448919|gaceta_449 (6)|que se tenga en c...|['actas', 'alguna...|      4|
# |         448844|    gaceta_513|gracias president...|['afectó', 'agend...|      0|
# |         448710|    gaceta_513|, por  jueves, 2 ...|['asocia', 'autor...|      3|
# |         448705|    gaceta_513|17.\t al grado de...|['albeiro', 'alva...|      2|
# +---------------+--------------+--------------------+--------------------+-------+
# only showing top 20 rows

# %%
int_df.printSchema()
# Out:
# root
#  |-- intervention_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- intervention_text: string (nullable = true)
#  |-- intervention_words: string (nullable = true)
#  |-- cluster: string (nullable = true)

# %%
esp_stopwords = [
    "a", "al", "algo", "algunas", "algunos", "ante", "antes", "aquel", "aquella",
    "aquellas", "aquellos", "aquí", "cada", "casi", "como", "con", "contra",
    "cual", "cuales", "cuando", "cuanta", "cuantas", "cuanto", "cuantos", "de",
    "del", "dentro", "donde", "dos", "el", "él", "ella", "ellas", "ellos", "en",
    "entre", "esa", "esas", "ese", "eso", "esos", "esta", "estas", "este",
    "estos", "lo", "los", "la", "las", "me", "mi", "mí", "mis", "nos", "nosotras",
    "nosotros", "o", "otra", "otras", "otro", "otros", "para", "pero", "poco",
    "por", "que", "qué", "se", "sí", "sin", "sobre", "su", "sus", "tu", "tú",
    "tus", "un", "una", "unas", "uno", "unos", "vosotras", "vosotros", "vuestra",
    "vuestras", "vuestro", "vuestros", "y", "ya"
]

# %%
#tokenize to create word "baskets"
tokenizer = Tokenizer(inputCol="intervention_text", outputCol="tokens")

stopwords_remover = StopWordsRemover(inputCol="tokens",
                                     outputCol="filtered_tokens",
                                     stopWords=esp_stopwords)
pipeline = Pipeline(stages=[tokenizer, stopwords_remover])
pipeline_model = pipeline.fit(int_df)

result_df = pipeline_model.transform(int_df)
result_df.select('tokens', 'filtered_tokens').show(10)
# Out:
# +--------------------+--------------------+
# |              tokens|     filtered_tokens|
# +--------------------+--------------------+
# |[de, acuerdo, con...|[acuerdo, observa...|
# |[albán, urbano, l...|[albán, urbano, l...|
# |[presidente, el, ...|[presidente, sigu...|
# |[perdone, un, seg...|[perdone, segundi...|
# |[antes, de, empez...|[empezar, orden, ...|
# |[celular, 3188620...|[celular, 3188620...|
# |[un, segundo, ya,...|[segundo, traslad...|
# |[doctora, lo, que...|[doctora, pasa, e...|
# |[continúa, el, se...|[continúa, señor,...|
# |[señor, president...|[señor, president...|
# +--------------------+--------------------+
# only showing top 10 rows

# %%
cluster_df_dict = {}
cluster_labels = [row[0] for row in result_df.select("cluster").distinct().collect()]

for label in cluster_labels:
    cluster_df = result_df.filter(result_df['cluster'] == label)
    cluster_df = cluster_df.filter((F.col('filtered_tokens').isNotNull()))
    cluster_df_dict[label] = cluster_df

# %% [markdown]
# ## FP Growth

# %%
test_df = result_df.filter(result_df['cluster'] == '1')
test_df.show(3)
# Out:
# [Stage 95:=====================================================>  (21 + 1) / 22]
# +---------------+--------------+--------------------+--------------------+-------+--------------------+--------------------+
# |intervention_id|    session_id|   intervention_text|  intervention_words|cluster|              tokens|     filtered_tokens|
# +---------------+--------------+--------------------+--------------------+-------+--------------------+--------------------+
# |         451438| gaceta_68 (7)|perdone un segund...|['comisión', 'deb...|      1|[perdone, un, seg...|[perdone, segundi...|
# |         451192|gaceta_456 (6)|antes de empezar ...|['asistir', 'comp...|      1|[antes, de, empez...|[empezar, orden, ...|
# |         450234| gaceta_49 (9)|continúa el señor...|['anglicana', 'ap...|      1|[continúa, el, se...|[continúa, señor,...|
# +---------------+--------------+--------------------+--------------------+-------+--------------------+--------------------+
# only showing top 3 rows

# %%
cleaned_df = test_df.withColumn("filtered_tokens", clean_tokens_udf(F.col("filtered_tokens")))
cleaned_df = cleaned_df.filter(F.size(F.col("filtered_tokens")) > 0)

cleaned_df.show()
# Out:
# 24/12/05 22:47:29 ERROR PythonUDFRunner: Python worker exited unexpectedly (crashed)
# org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/software/spark-3.3.2-el8-x86_64/python/lib/pyspark.zip/pyspark/worker.py", line 666, in main
#     eval_type = read_int(infile)
#   File "/software/spark-3.3.2-el8-x86_64/python/lib/pyspark.zip/pyspark/serializers.py", line 595, in read_int
#     raise EOFError
# EOFError
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:552)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$2.read(PythonUDFRunner.scala:86)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$2.read(PythonUDFRunner.scala:68)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:505)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:491)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage2.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec$$anon$1.hasNext(WholeStageCodegenExec.scala:760)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:136)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:548)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1504)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:551)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1130)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:630)
# 	at java.base/java.lang.Thread.run(Thread.java:832)
# Caused by: org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 ERROR PythonUDFRunner: This may have been caused by a prior exception:
# org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 ERROR Executor: Exception in task 3.0 in stage 119.0 (TID 922)
# org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 ERROR PythonUDFRunner: Python worker exited unexpectedly (crashed)
# org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/software/spark-3.3.2-el8-x86_64/python/lib/pyspark.zip/pyspark/worker.py", line 666, in main
#     eval_type = read_int(infile)
#   File "/software/spark-3.3.2-el8-x86_64/python/lib/pyspark.zip/pyspark/serializers.py", line 595, in read_int
#     raise EOFError
# EOFError
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:552)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$2.read(PythonUDFRunner.scala:86)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$2.read(PythonUDFRunner.scala:68)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:505)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:491)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage2.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec$$anon$1.hasNext(WholeStageCodegenExec.scala:760)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:136)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:548)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1504)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:551)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1130)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:630)
# 	at java.base/java.lang.Thread.run(Thread.java:832)
# Caused by: org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 ERROR PythonUDFRunner: This may have been caused by a prior exception:
# org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 ERROR Executor: Exception in task 9.0 in stage 119.0 (TID 928)
# org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 3.0 in stage 119.0 (TID 922) (midway3-0096.rcc.local executor driver): org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
#
# 24/12/05 22:47:29 ERROR TaskSetManager: Task 3 in stage 119.0 failed 1 times; aborting job
# 24/12/05 22:47:29 ERROR PythonUDFRunner: Python worker exited unexpectedly (crashed)
# org.apache.spark.api.python.PythonException: Traceback (most recent call last):
#   File "/software/spark-3.3.2-el8-x86_64/python/lib/pyspark.zip/pyspark/worker.py", line 666, in main
#     eval_type = read_int(infile)
#   File "/software/spark-3.3.2-el8-x86_64/python/lib/pyspark.zip/pyspark/serializers.py", line 595, in read_int
#     raise EOFError
# EOFError
#
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.handlePythonException(PythonRunner.scala:552)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$2.read(PythonUDFRunner.scala:86)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$2.read(PythonUDFRunner.scala:68)
# 	at org.apache.spark.api.python.BasePythonRunner$ReaderIterator.hasNext(PythonRunner.scala:505)
# 	at org.apache.spark.InterruptibleIterator.hasNext(InterruptibleIterator.scala:37)
# 	at scala.collection.Iterator$$anon$11.hasNext(Iterator.scala:491)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$GeneratedIteratorForCodegenStage2.processNext(Unknown Source)
# 	at org.apache.spark.sql.execution.BufferedRowIterator.hasNext(BufferedRowIterator.java:43)
# 	at org.apache.spark.sql.execution.WholeStageCodegenExec$$anon$1.hasNext(WholeStageCodegenExec.scala:760)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at org.apache.spark.shuffle.sort.BypassMergeSortShuffleWriter.write(BypassMergeSortShuffleWriter.java:140)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:99)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:52)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:136)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:548)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1504)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:551)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1130)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:630)
# 	at java.base/java.lang.Thread.run(Thread.java:832)
# Caused by: org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 ERROR PythonUDFRunner: This may have been caused by a prior exception:
# org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 10.0 in stage 119.0 (TID 929) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 4.0 in stage 119.0 (TID 923) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/07/temp_shuffle_6d70ce5a-ff40-47d6-b949-c4d5ba716a64
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_05a9a0fb-2ecb-414d-9823-34f728d8d541
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/28/temp_shuffle_a9d44f66-45e9-477d-a572-990641c10e9d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/01/temp_shuffle_483e31b4-d014-4a94-b5fa-f872bdb29337
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/11/temp_shuffle_20770f14-b204-409e-b201-29437f656e69
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/25/temp_shuffle_4234d54e-ad05-4914-8283-700a9f84a7a6
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/34/temp_shuffle_af4a554b-468a-4c35-aa10-6e29a706ccac
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1e/temp_shuffle_be31d674-2a1f-4653-8dd7-00c74aa022a1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_092285c2-a233-44a4-a7d1-af115f628366
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/36/temp_shuffle_c9080167-f24c-476a-a993-602dfbfb4d5e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_96bf36d7-26a8-4cad-97a5-111e5c84bcb0
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/24/temp_shuffle_71f8a987-8239-4569-8c9e-8ee18385425a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/38/temp_shuffle_ae9ded21-c166-46c5-824b-bcf1f8d87089
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/34/temp_shuffle_e8c51569-6a65-48b6-be9c-f8a1d613294e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2c/temp_shuffle_dad69d61-0d62-4258-bf55-6ea886426cf8
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/20/temp_shuffle_1936ba69-32f4-4756-a6e0-d6deac7b843b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/09/temp_shuffle_95f74caa-bb6d-4582-9563-d743f49dcc7b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/15/temp_shuffle_f64a7952-78c2-435a-919d-035a09d1935f
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/30/temp_shuffle_02c68aff-8ad2-45dd-bb85-4ef973f63f4e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2e/temp_shuffle_74ab5d3a-a50e-4438-9ee0-6b2027f862ff
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/34/temp_shuffle_1ee68856-71f3-45ba-bd8d-948990c78a35
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1b/temp_shuffle_e6a3c121-51df-4433-bc4a-47e512c4b0eb
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/16/temp_shuffle_4f9ae1cd-5d8c-4536-a0ec-7414e8f6c2b1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/29/temp_shuffle_d8c174ee-9655-4e0d-bdd6-76541622b2cc
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2e/temp_shuffle_773b9e75-9495-4e30-9883-1be128087542
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_77a93397-810d-4991-9c35-2b0c237ccc21
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 2.0 in stage 119.0 (TID 921) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3a/temp_shuffle_dfe2d35f-ba0d-4087-8efe-8aa80cd29138
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/17/temp_shuffle_5f8531b5-7eea-4705-adc6-fb29d0d65d5d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_411bb104-f6e8-4510-bbac-9c89a403a89b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/18/temp_shuffle_f17eeeee-c747-4e6a-8c9c-f5fdead01219
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/22/temp_shuffle_8fe0d67f-8f73-4adc-b16b-40de3d90dac1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/16/temp_shuffle_a13747d8-0731-4109-97d4-6c9c0c061a94
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2e/temp_shuffle_5eb182f5-20b7-4625-8144-57c4d694d16e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/05/temp_shuffle_6e70fce8-d616-465f-9e53-2f0097b040b0
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0c/temp_shuffle_2e8c72b0-704e-4f7f-962f-2de1fef88ff7
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/39/temp_shuffle_ba81371b-673f-40cd-ba87-5d92d29b94ae
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2e/temp_shuffle_f3ff47aa-6a81-46de-ab69-18ee055c6d8b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/39/temp_shuffle_43d9ce2d-2fee-4412-bb59-3dbabeabfc17
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2c/temp_shuffle_595e41aa-70c4-47e1-a4ed-b394c22d6f79
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/18/temp_shuffle_ea30acef-dd70-4a0f-bf51-40faec910895
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/31/temp_shuffle_100bc7a5-5709-44d0-89a4-4b004ddc5484
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/03/temp_shuffle_99180a0a-f59e-4b33-b857-5b403f5e38eb
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_b392b64c-7b8d-4059-89ec-8ef1d8ec4202
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/01/temp_shuffle_778299cd-1e13-4552-8dfe-6a62b98d6eed
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 7.0 in stage 119.0 (TID 926) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/16/temp_shuffle_e1147eff-6766-4640-9ac3-8fb597828ff6
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/22/temp_shuffle_1fb1c72f-7f52-42b4-9789-7227fd1efc6c
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/36/temp_shuffle_568ce101-2240-4334-8324-9e05dfe17c6d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/16/temp_shuffle_9e18c021-4a46-4633-8537-3c4e78840f66
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/31/temp_shuffle_190f7a67-2354-4ad1-9219-fdcd2e869f65
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_07ae8c11-627f-4850-b196-aea50b892f9e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/33/temp_shuffle_614f13ed-cd87-4e9e-bef3-567507dc9506
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3b/temp_shuffle_a9443a2c-ab96-4d8d-9422-f57441fb2d47
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0d/temp_shuffle_4e0fb70c-a320-4589-80d8-be500249baad
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/06/temp_shuffle_016a410f-611f-4362-bdb0-54aee8c3efe9
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/35/temp_shuffle_8dcdbfd3-3e07-46bd-ad1b-b7dde8a7e291
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/23/temp_shuffle_1114c750-4951-4301-b236-19520b04d744
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1e/temp_shuffle_1dd2af5d-3f1a-45ab-b5e0-4e840fcc90da
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/03/temp_shuffle_e40c778d-353a-417b-9af0-333bfcb65ae1
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 2.0 in stage 120.0 (TID 932) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/09/temp_shuffle_9de2b59a-012a-4e6d-830c-3e00abcd42b4
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/35/temp_shuffle_43e89866-1ac6-4b8b-b0ab-07bada491688
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1b/temp_shuffle_562b5b74-2c9e-4ed2-8fc9-5cd5945faa4d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0b/temp_shuffle_52d0d01b-0cee-4890-8920-35f85bb98ab6
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/29/temp_shuffle_88ae7b52-b1b9-40aa-bdf3-86ee238fc80a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/06/temp_shuffle_b47f5267-7a57-451d-860d-95eab6053e30
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/16/temp_shuffle_404b67ef-0d05-4384-8293-6c33bbcd6784
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/33/temp_shuffle_17aafad3-2b21-41ab-9529-447d84020c79
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/10/temp_shuffle_17b9db2d-3230-421f-893f-67da87a0ac12
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1a/temp_shuffle_a774224d-3c2c-4afc-91f8-f44b81303c1b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0c/temp_shuffle_f2cc8a4d-27ff-48d2-885c-be5b96f5eb64
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0a/temp_shuffle_6daa3af9-70b3-4c5e-9025-cd3335c3ecca
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1e/temp_shuffle_5991cde3-e5bf-4656-b30d-f965b8d93ca0
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/13/temp_shuffle_bcb21ef0-5dba-4d6d-8f9b-77fbba0232a9
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/07/temp_shuffle_df054e0a-d432-4ad6-a108-26f57a78fd9d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2c/temp_shuffle_50e62eac-55cc-4324-9d95-fb98e3344cb1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/39/temp_shuffle_e16484f3-2b26-4422-b4cd-06d87f1bc85b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/16/temp_shuffle_0c516e52-d6c2-441b-b46f-911c77c158ef
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1d/temp_shuffle_8b1af87e-769d-474e-a213-2bfcd01dade1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/09/temp_shuffle_9034788c-2765-49d3-af11-81ea80aa75fd
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/37/temp_shuffle_5e9d6366-6ef4-40d1-86e3-104d1fdd6420
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/28/temp_shuffle_efea37d8-62ff-4639-ac80-0c50538c525a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/17/temp_shuffle_733bdd4e-f0fb-4905-96a4-4d90ceca024a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0c/temp_shuffle_f623744b-6f0e-4802-a05d-83917cb0f19e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/08/temp_shuffle_e738ecd4-273f-4075-8b7d-8eef8f22b140
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/06/temp_shuffle_567bdc8f-e47f-4514-b073-9859a40accd1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/00/temp_shuffle_90d7e383-90ba-483e-8859-bf26478e1416
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3f/temp_shuffle_faf13aaf-02ba-4190-8533-ecb7d785eaaa
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/07/temp_shuffle_961136a2-1e6a-4e2b-b8d5-e30aac7dd2ff
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2d/temp_shuffle_a39014af-1eba-4de9-bf9a-f2b12d6874ee
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/08/temp_shuffle_ecb87e45-d6ea-4fc7-bf83-b9852f3da4dc
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/24/temp_shuffle_76841580-e75c-4784-8647-da57a8f6daf9
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/21/temp_shuffle_1b387a21-9229-45f6-8042-43d6ae44c4e5
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/33/temp_shuffle_5db6c76f-fd2e-49a5-ae0c-6cd2d5808789
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1b/temp_shuffle_9971d4a6-94f1-47be-8bf7-f64e5d74283f
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2b/temp_shuffle_2d6d1406-0484-4a3e-af73-5f0fd8272d34
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/29/temp_shuffle_6d357f73-78dc-470a-874a-01f859a9b116
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/39/temp_shuffle_51e117e3-40b5-4a1d-9732-99d06384cf3c
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/21/temp_shuffle_7c0ce267-7f7c-446b-9a7d-a7093079c90c
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/06/temp_shuffle_e8558f7f-f8a6-4d72-b028-c4cbde1aa984
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/04/temp_shuffle_e2bdd1c0-33a1-4383-bcc4-0cf70208b28d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/20/temp_shuffle_947b5df4-8d20-4ea7-99a0-fa1fc3ac6178
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/19/temp_shuffle_e1de9e1a-e47a-4f81-ae63-2d3147f02c55
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/18/temp_shuffle_f429ccc6-716b-4e32-a9f1-83d21391d7ac
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_19f3bafd-51ec-46cf-84be-6e8cdaea2457
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0a/temp_shuffle_c241d2da-47b5-4372-af44-b178ac2a54b1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/23/temp_shuffle_4bee8456-59c2-4a6c-a2e1-48cff66a34c7
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3c/temp_shuffle_1ce75e29-7b5c-423b-b664-8463ce445c38
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/19/temp_shuffle_ae085891-8135-49af-a22e-78c7da24233b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/38/temp_shuffle_4b7dbff7-4ac0-4e93-a8f3-06c980088644
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1c/temp_shuffle_c29651b3-5ec9-4baa-8f38-46368403392e
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/37/temp_shuffle_51d4f08b-c3c9-43c5-b44a-d0bd6a4d4fb3
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/12/temp_shuffle_329ade68-dcc3-43e6-a178-158892c9482b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/04/temp_shuffle_238a83d3-76de-4314-85e7-4600db28a79a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/27/temp_shuffle_97c65ccc-9750-45f8-b0ee-8844c896fd4a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3c/temp_shuffle_f70a1bce-c775-4648-99de-4dad666c405d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/18/temp_shuffle_716c5830-ae65-46b7-b733-60daed51eb24
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2d/temp_shuffle_2b5aee7f-4e04-42c5-820b-e42fd5b4b3b3
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3d/temp_shuffle_ef727f15-7b23-45cd-bded-a68fa216470b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3e/temp_shuffle_96b4b5be-3159-4a43-9052-628aac5e83ae
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_fccb7e7e-83e6-4655-80aa-7088e1a6d9ae
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2a/temp_shuffle_93c3c636-6edc-48ed-be00-89480b77740c
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3f/temp_shuffle_bb0087c5-ea3f-4555-b11d-7e1a3339da8d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/22/temp_shuffle_96783366-2681-4010-9866-35db91fe1a4a
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2a/temp_shuffle_6e486f9d-1a4e-4699-9e8e-b9ec4d895d82
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2e/temp_shuffle_006ce72d-f67e-4ada-abb6-c458ba2a671c
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3a/temp_shuffle_213ae975-97d0-4561-9d5f-4da3053ef2b1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3c/temp_shuffle_37cb93da-8a02-4aef-b118-e9c7a13d8795
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/33/temp_shuffle_04ffc798-e46d-4820-9f71-befbaa89fa7c
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/19/temp_shuffle_3adc0e0e-8a43-4430-8408-efb21173a9fa
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/20/temp_shuffle_d72a93ae-638e-458e-a50c-11bea7d651f1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_0e2804d1-7a38-4e08-8f35-5f1063f8cfd1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2c/temp_shuffle_fc3a9e4d-8444-4689-974c-baab132be8fc
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/01/temp_shuffle_4a880828-cf80-4bf2-853c-1c52f6156bf8
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3a/temp_shuffle_00d0c507-163b-40a3-873c-00623837c414
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/22/temp_shuffle_c132c071-8fe4-4c7e-ae4f-04993829a1d3
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/39/temp_shuffle_0ab14f7b-b79f-4083-a085-0e68948d64d8
# ...
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/36/temp_shuffle_ff78b244-90d3-460c-ba5f-eeb51ab54751
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_9c1c5caa-0a02-48c4-aad4-f701e7ec1aa4
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1e/temp_shuffle_4fcb6da2-56ec-47e8-8ae7-940e3862235d
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/38/temp_shuffle_867fbc8e-d761-4a97-b097-d67e6309272b
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3a/temp_shuffle_9c934a85-3544-4f9d-bd8c-044db715bae2
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/30/temp_shuffle_9c35d3de-0d8d-46ca-a286-57cd44b37797
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/22/temp_shuffle_521ff433-b209-4bb2-866e-e43177991607
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/14/temp_shuffle_b6ad3b83-fc38-4eb9-8ef4-479cb2aabc81
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/29/temp_shuffle_6ced9438-0990-4135-96c3-82d198394495
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/14/temp_shuffle_7064633c-ba0d-4e51-97da-6d1457de2842
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3e/temp_shuffle_b41c8e57-e0a0-4b3c-985b-82c165f0ffd9
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2c/temp_shuffle_f79fe25c-6467-4884-b881-d8b20ab7f565
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0f/temp_shuffle_59b5cf4a-6e92-47c9-8151-25d6c48c0604
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3e/temp_shuffle_a6ec4126-e653-478f-a447-3f4793ba7ab6
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/33/temp_shuffle_b1087282-62e2-44e5-b312-88414ea428a5
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/15/temp_shuffle_64de497f-c623-4b8f-9229-02a3dfd63bd6
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0c/temp_shuffle_dca80d23-32d2-42bb-a533-422a55e3ed01
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/05/temp_shuffle_f499d27a-7635-4d20-8749-15524766c516
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/26/temp_shuffle_f38950fc-06c1-4cb4-96bf-580042e91674
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3c/temp_shuffle_501764a7-249e-4a16-9cfe-0c26b1d4f5a7
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/23/temp_shuffle_693dfdc5-bb7a-4a75-81c3-81037f56ecf2
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_a27bea30-103c-4fc1-b246-936eb697d1de
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0d/temp_shuffle_ccb4ed98-32e8-4a80-988c-4d1dbae1dd61
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/36/temp_shuffle_53091d6d-ce9f-41fa-b000-d9a800951bda
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2c/temp_shuffle_2c061b0a-fcae-49cf-8a06-f79916ed24f9
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0d/temp_shuffle_ac22ce55-e2ee-46f6-a948-419abf5cf4a1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/35/temp_shuffle_3e7f9426-e79f-4d4e-b2eb-aaaf05686142
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/27/temp_shuffle_2d53c4ee-5fc0-422c-b578-4ee32bf011e6
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1f/temp_shuffle_94228b1b-c163-4e0d-931a-f1cde78aadca
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1d/temp_shuffle_fa753e57-32d4-4364-842e-2734a25397d7
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1b/temp_shuffle_ebe250c5-00c0-4103-b173-ad4253cc7a79
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/25/temp_shuffle_645cd818-3c54-4407-8be1-88de49b97715
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/38/temp_shuffle_12db828c-a28c-47fe-a4d2-24553cf12bc4
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/03/temp_shuffle_47cb082a-c8cf-4ee0-9b3e-2dd4cb301c88
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/04/temp_shuffle_0c3d1b75-e7d3-4209-8fb4-62f5293e4bdd
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/1a/temp_shuffle_6b254931-8b23-4915-84f0-8a209b7d5a79
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/24/temp_shuffle_3afa6157-fb07-41be-a9f7-6ffab6118992
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/2b/temp_shuffle_eb35f8f2-8688-4da8-890b-aec4b7b96914
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/33/temp_shuffle_002c202f-b0b0-47b2-abb7-e98e407cd009
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/3f/temp_shuffle_953ce585-913f-4bf0-b71b-110c4fdb0f90
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/08/temp_shuffle_c24e56e0-dcf3-45ba-83e6-4d580fd1f674
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/35/temp_shuffle_7da5c697-0fc5-4c02-be2c-44a0212474a1
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/22/temp_shuffle_384a0058-7521-4639-8e1a-8fb196d3fe79
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/05/temp_shuffle_47d0358d-7acc-4003-92b4-db41a3f4be49
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/36/temp_shuffle_5f045de1-e410-4c38-977f-ba7ca1efb6bb
# 24/12/05 22:47:29 WARN DiskBlockObjectWriter: Error deleting /tmp/blockmgr-ba21d64c-375f-4e8c-a6a6-4db8f0d256d6/0e/temp_shuffle_07cf4a7e-05e7-4bfa-9a3f-1e4577f2a3b0
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 6.0 in stage 119.0 (TID 925) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 0.0 in stage 119.0 (TID 919) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 5.0 in stage 119.0 (TID 924) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 1.0 in stage 119.0 (TID 920) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# 24/12/05 22:47:29 WARN TaskSetManager: Lost task 8.0 in stage 119.0 (TID 927) (midway3-0096.rcc.local executor driver): TaskKilled (Stage cancelled)
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# Cell In[64], line 4
#       1 cleaned_df = test_df.withColumn("filtered_tokens", clean_tokens_udf(F.col("filtered_tokens")))
#       2 cleaned_df = cleaned_df.filter(F.size(F.col("filtered_tokens")) > 0)
# ----> 4 cleaned_df.show()
#
# File /software/spark-3.3.2-el8-x86_64/python/pyspark/sql/dataframe.py:606, in DataFrame.show(self, n, truncate, vertical)
#     603     raise TypeError("Parameter 'vertical' must be a bool")
#     605 if isinstance(truncate, bool) and truncate:
# --> 606     print(self._jdf.showString(n, 20, vertical))
#     607 else:
#     608     try:
#
# File /software/spark-3.3.2-el8-x86_64/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /software/spark-3.3.2-el8-x86_64/python/pyspark/sql/utils.py:190, in capture_sql_exception.<locals>.deco(*a, **kw)
#     188 def deco(*a: Any, **kw: Any) -> Any:
#     189     try:
# --> 190         return f(*a, **kw)
#     191     except Py4JJavaError as e:
#     192         converted = convert_exception(e.java_exception)
#
# File /software/spark-3.3.2-el8-x86_64/python/lib/py4j-0.10.9.5-src.zip/py4j/protocol.py:326, in get_return_value(answer, gateway_client, target_id, name)
#     324 value = OUTPUT_CONVERTER[type](answer[2:], gateway_client)
#     325 if answer[1] == REFERENCE_TYPE:
# --> 326     raise Py4JJavaError(
#     327         "An error occurred while calling {0}{1}{2}.\n".
#     328         format(target_id, ".", name), value)
#     329 else:
#     330     raise Py4JError(
#     331         "An error occurred while calling {0}{1}{2}. Trace:\n{3}\n".
#     332         format(target_id, ".", name, value))
#
# Py4JJavaError: An error occurred while calling o3505.showString.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 3 in stage 119.0 failed 1 times, most recent failure: Lost task 3.0 in stage 119.0 (TID 922) (midway3-0096.rcc.local executor driver): org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException
#
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.failJobAndIndependentStages(DAGScheduler.scala:2672)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2(DAGScheduler.scala:2608)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$abortStage$2$adapted(DAGScheduler.scala:2607)
# 	at scala.collection.mutable.ResizableArray.foreach(ResizableArray.scala:62)
# 	at scala.collection.mutable.ResizableArray.foreach$(ResizableArray.scala:55)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:2607)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1(DAGScheduler.scala:1182)
# 	at org.apache.spark.scheduler.DAGScheduler.$anonfun$handleTaskSetFailed$1$adapted(DAGScheduler.scala:1182)
# 	at scala.Option.foreach(Option.scala:407)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:1182)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2860)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2802)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2791)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# Caused by: org.apache.spark.SparkException: Failed to execute user defined function (Tokenizer$$Lambda$3927/0x0000000801b0bb38: (string) => array<string>)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors$.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala:190)
# 	at org.apache.spark.sql.errors.QueryExecutionErrors.failedExecuteUserDefinedFunctionError(QueryExecutionErrors.scala)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.ScalaUDF_0$(Unknown Source)
# 	at org.apache.spark.sql.catalyst.expressions.GeneratedClass$SpecificMutableProjection.apply(Unknown Source)
# 	at org.apache.spark.sql.execution.python.EvalPythonExec.$anonfun$doExecute$10(EvalPythonExec.scala:127)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$$anon$10.next(Iterator.scala:461)
# 	at scala.collection.Iterator$GroupedIterator.takeDestructively(Iterator.scala:1161)
# 	at scala.collection.Iterator$GroupedIterator.go(Iterator.scala:1176)
# 	at scala.collection.Iterator$GroupedIterator.fill(Iterator.scala:1214)
# 	at scala.collection.Iterator$GroupedIterator.hasNext(Iterator.scala:1217)
# 	at scala.collection.Iterator$$anon$10.hasNext(Iterator.scala:460)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.api.python.PythonRDD$.writeIteratorToStream(PythonRDD.scala:307)
# 	at org.apache.spark.sql.execution.python.PythonUDFRunner$$anon$1.writeIteratorToStream(PythonUDFRunner.scala:53)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.$anonfun$run$1(PythonRunner.scala:431)
# 	at org.apache.spark.util.Utils$.logUncaughtExceptions(Utils.scala:2066)
# 	at org.apache.spark.api.python.BasePythonRunner$WriterThread.run(PythonRunner.scala:265)
# Caused by: java.lang.NullPointerException

# %%
cleaned_df.printSchema()
cleaned_df.show()
# Out:
# root
#  |-- intervention_id: string (nullable = true)
#  |-- session_id: string (nullable = true)
#  |-- intervention_text: string (nullable = true)
#  |-- intervention_words: string (nullable = true)
#  |-- cluster: string (nullable = true)
#  |-- tokens: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- filtered_tokens: array (nullable = true)
#  |    |-- element: string (containsNull = true)
# [Stage 113:====================================================>  (21 + 1) / 22]
# +---------------+--------------+--------------------+--------------------+-------+--------------------+--------------------+
# |intervention_id|    session_id|   intervention_text|  intervention_words|cluster|              tokens|     filtered_tokens|
# +---------------+--------------+--------------------+--------------------+-------+--------------------+--------------------+
# |         451438| gaceta_68 (7)|perdone un segund...|['comisión', 'deb...|      1|[perdone, un, seg...|[perdone, segundi...|
# |         451192|gaceta_456 (6)|antes de empezar ...|['asistir', 'comp...|      1|[antes, de, empez...|[empezar, orden, ...|
# |         450234| gaceta_49 (9)|continúa el señor...|['anglicana', 'ap...|      1|[continúa, el, se...|[continúa, señor,...|
# |         450076|gaceta_134 (7)|señor presidente,...|['después', 'día'...|      1|[señor, president...|[señor, es, veo, ...|
# |         449987|    gaceta_634|austed senador al...|['alirio', 'aquí'...|      1|[austed, senador,...|[austed, senador,...|
# |         450893|   gaceta_1536|se acabó el tiemp...|['acabó', 'aceta'...|      1|[se, acabó, el, t...|[acabó, tiempo, b...|
# |         450679|    gaceta_779|cabrales baquero ...|['abraham', 'baqu...|      1|[cabrales, baquer...|[cabrales, baquer...|
# |         448755|    gaceta_513|se designan los m...|['ascensos', 'com...|      1|[se, designan, lo...|[designan, mismos...|
# |         447303|    gaceta_377|perfecto, señora ...|['carlos', 'comis...|      1|[perfecto,, señor...|[señora, entonces...|
# |         447126|    gaceta_377|muchísimas gracia...|['andrés', 'arran...|      1|[muchísimas, grac...|[muchísimas, grac...|
# |         451398| gaceta_68 (7)|doctor bérner zam...|['bérner', 'docto...|      1|[doctor, bérner, ...|[doctor, bérner, ...|
# |         449975|    gaceta_634|listo ministra, p...|['ana', 'bueno', ...|      1|[listo, ministra,...|[listo, bueno, re...|
# |         449511| gaceta_98 (5)|se concede el uso...|['andrés', 'conce...|      1|[se, concede, el,...|[concede, uso, pa...|
# |         447394|gaceta_619 (8)|quería antes info...|['agilidad', 'bre...|      1|[quería, antes, i...|[quería, informar...|
# |         444967| gaceta_98 (1)|doctor juan carlo...|['boyacá', 'bueno...|      1|[doctor, juan, ca...|[doctor, juan, fe...|
# |         449036|gaceta_789 (4)|continuamos con e...|['adolescencia', ...|      1|[continuamos, con...|[continuamos, rep...|
# |         449620| gaceta_98 (5)|se concede el uso...|['agricultura', '...|      1|[se, concede, el,...|[concede, uso, pa...|
# |         449509| gaceta_98 (5)|continúa con el u...|['carlos', 'conti...|      1|[continúa, con, e...|[continúa, uso, p...|
# |         449191|gaceta_116 (8)|el presidente del...|['andrade', 'cont...|      1|[el, presidente, ...|[presidente, hono...|
# |         449090|gaceta_138 (3)|gracias señora se...|['algún', 'bienve...|      1|[gracias, señora,...|[gracias, señora,...|
# +---------------+--------------+--------------------+--------------------+-------+--------------------+--------------------+
# only showing top 20 rows
